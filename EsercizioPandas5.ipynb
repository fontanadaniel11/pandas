# %% [markdown]
# <a href="https://colab.research.google.com/github/fontanadaniel11/pandas/blob/main/EsercizioPandas5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. caricare il file

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

# %%
titanic = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/LOTORTO RICCARDO - titanic.csv",  delimiter = ";")

# %% [markdown]
# 2. mostare i record dal 20 al 40

# %%
titanic[20:41]
# Out:
#     PassengerId  Survived  Pclass  \
# 20           21         0       2
# 21           22         1       2
# 22           23         1       3
# 23           24         1       1
# 24           25         0       3
# 25           26         1       3
# 26           27         0       3
# 27           28         0       1
# 28           29         1       3
# 29           30         0       3
# 30           31         0       1
# 31           32         1       1
# 32           33         1       3
# 33           34         0       2
# 34           35         0       1
# 35           36         0       1
# 36           37         1       3
# 37           38         0       3
# 38           39         0       3
# 39           40         1       3
# 40           41         0       3
#
#                                                  Name     Sex   Age  SibSp  \
# 20                               Fynney; Mr. Joseph J    male  35.0      0
# ...

# %% [markdown]
# 3. mostare le prime due colonne

# %%
titanic.iloc[:, 0:2]
# Out:
#      PassengerId  Survived
# 0              1         0
# 1              2         1
# 2              3         1
# 3              4         1
# 4              5         0
# ..           ...       ...
# 886          887         0
# 887          888         1
# 888          889         0
# 889          890         1
# 890          891         0
#
# [891 rows x 2 columns]

# %% [markdown]
# 4. trovare la somma delle età

# %%
titanic["Age"].sum()
# Out:
# 21205.17

# %% [markdown]
# 5. il nome delle persone con età maggiore a 40

# %%
titanic[titanic["Age"] >= 40][["Name"]]
# Out:
#                                                   Name
# 6                              McCarthy; Mr. Timothy J
# 11                            Bonnell; Miss. Elizabeth
# 15                    Hewlett; Mrs. (Mary D Kingcome)
# 30                            Uruchurtu; Don. Manuel E
# 33                               Wheadon; Mr. Edward H
# ..                                                 ...
# 862  Swift; Mrs. Frederick Joel (Margaret Welles Ba...
# 865                           Bystrom; Mrs. (Karolina)
# 871   Beckwith; Mrs. Richard Leonard (Sallie Monypeny)
# 873                        Vander Cruyssen; Mr. Victor
# 879      Potter; Mrs. Thomas Jr (Lily Alexenia Wilson)
#
# [163 rows x 1 columns]

# %% [markdown]
# 6. il nome della persona più giovane

# %%
titanic[titanic["Age"] == titanic["Age"].min()][["Name"]]
# Out:
#                                 Name
# 803  Thomas; Master. Assad Alexander

# %% [markdown]
# 7. aggiungere 5 all'età delle persone che si chiamano William

# %%
titanic["Age"][titanic["Name"].str.contains("William")] = titanic["Age"][titanic["Name"].str.contains("William")] + 5
titanic[titanic["Name"].str.contains("William")]
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#      PassengerId  Survived  Pclass  \
# 4              5         0       3
# 12            13         0       3
# 17            18         1       2
# 23            24         1       1
# 31            32         1       1
# ..           ...       ...     ...
# 802          803         1       1
# 810          811         0       3
# 864          865         0       2
# 880          881         1       2
# 885          886         0       3
#
#                                                Name     Sex   Age  SibSp  \
# 4                          Allen; Mr. William Henry    male  40.0      0
# ...

# %% [markdown]
# 8. visualizzare i passeggeri di cui si conosce la cabina

# %%
titanic[titanic["Cabin"].notnull()]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings; Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle; Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy; Mr. Timothy J    male  54.0      0
# 10                     Sandstrom; Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell; Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# 9. visualizzare il numero dei non sopravvissuti

# %%
titanic[titanic["Survived"] == 0]["Survived"].count()
# Out:
# 549

# %% [markdown]
# 10. visualizzare il numero medio della tariffa dei passeggeri in seconda classe

# %%
titanic[titanic["Pclass"] == 2]["Fare"].mean()
# Out:
# 20.662183152173913

# %% [markdown]
# 11. aumentare del 20% tutte le età

# %%
titanic["Age"] = titanic["Age"] * 1.2
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund; Mr. Owen Harris    male  26.4      1
# 1  Cumings; Mrs. John Bradley (Florence Briggs Th...  female  45.6      1
# 2                             Heikkinen; Miss. Laina  female  31.2      0
# 3       Futrelle; Mrs. Jacques Heath (Lily May Peel)  female  42.0      1
# 4                           Allen; Mr. William Henry    male  48.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S
